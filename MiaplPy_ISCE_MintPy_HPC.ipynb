# %% [markdown]
# # Commands HPC
#
# - **Job submision:** sbatch file_name.sh
# - **Job submision #2:** srun
# - **Job monitoring:** squeue -u enr30065
# - **Jobs list:** sacct --array or sacct -L
# - **Cancel a job:** scancel
# - **module list:** activated modules
# - **module avail:** available modules
# - **module spider matplotlib:** matplotlib versions available use spider also to know how to load a module
# - **module load matplotlib/version:** to load a software
# - **[SLURM](https://slurm.schedmd.com/quickstart.html)**

# %%
####EXAMPLE file_name.sh####

# %% [markdown]
# ![Screenshot%202024-11-15%20at%2016.03.59.png](attachment:Screenshot%202024-11-15%20at%2016.03.59.png)

# %% [markdown]
# # Miaplpy

# %% [markdown]
# ## Installation
#
# **1. Create a txt in Home directory: requirements.txt**
#
# `cartopy
#
# cvxopt
#
# rasterio
#
# dask>=1.0
#
# dask-jobqueue>=0.3
#
# defusedxml
#
# h5py
#
# lxml
#
# matplotlib
#
# numpy
#
# pip
#
# pyproj
#
# scikit-image
#
# scipy
#
# gdal
#
# mintpy
#
# cython
#
# setuptools
#
# pulp
#
# pyaps3>=0.3
#
# pykml>=0.2
#
# pyresample
#
# pysolid`
#
# **2. Clone miaplpy git, load modules, create vitual environment, install program**
#
# `git clone https://github.com/insarlab/MiaplPy.git
#
# module load StdEnv/2020 gcc/9.3.0 python/3.10.2 proj/9.0.1 gdal/3.5.1 isce2/2.6.3
#
# virtualenv miaplypyenv
#
# source miaplypyenv/bin/activate
#
# pip install -r requirements.txt
#
# cd MiaplPy
#
# pip install .`
#
# **3. Test installation:**
#
# miaplpyApp -h
#
# **4. Install Snaphu:**
#
# [Snaphu](https://github.com/insarlab/MiaplPy/blob/main/docs/installation.md)
#
#
# **New runs: Activate environment**
#
# `module load StdEnv/2020 gcc/9.3.0 python/3.10.2 proj/9.0.1 gdal/3.5.1 isce2/2.6.3
#
# source ${HOME}/miaplypyenv/bin/activate`

# %% [markdown]
# ## Run MintplPy with S1
#
# - [MiaplPy JN tutorial](https://nbviewer.org/github/insarlab/MiaplPy_notebooks/blob/main/miaplpyApp.ipynb)

# %% [markdown]
# # Jupyter hub HPC
# 0. [Original tutorial:](https://github.com/tvhahn/compute-canada-hpc/blob/master/02-create-notebooks/02-notebook-setup.md)
# 1. Activate the virtual environment in HOME
#       - module load StdEnv/2020 gcc/9.3.0 python/3.10.2 proj/9.0.1 gdal/3.5.1 isce2/2.6.3
#       - source  ${HOME}/miaplypyenv/bin/activate

# %% [markdown]
# 2. Move to scrach
# 3. Request resorces: salloc --time=8:0:0 --ntasks=1 --cpus-per-task=8 --mem-per-cpu=4000 --account=def-yjiang1 srun $VIRTUAL_ENV/bin/notebook.sh

# %% [markdown]
# 4. Open a new terminal to open the tunnel

# %% [markdown]
#     4.1 Close any other JN sesion

# %% [markdown]
#     4.2 Type e.g., ssh -L 8888:cdr136.int.cedar.computecanada.ca:8888 enr30065@cedar.alliancecan.ca)

# %% [markdown]
#     4.3 Enter your password

# %% [markdown]
#     4.4 Launched the JN in your browser (e.g., http://localhost:8888/?token=10d8d9e93944ee10505631e08460c57af4a00193d9c0970e)

# %% [markdown]
# **Notes**
# - Create the virtual environment in the home directory.
# - user: def-yjiang1 for requesting resources
# - Before running the tunnel, close any other JN session.
# - In the tunnel, use your normal password
# - To run the JN move to scrach
# - To Install new packages: pip install --no-index utils
# - Use the first node that appears after this message and its last version. To access the server, open this file in a browser

# %% [markdown]
# # ISCE

# %% [markdown]
# ## Installation
#
# - [ISCE github](https://github.com/isce-framework/isce2?tab=readme-ov-file)
#
# - [Alliance HPCs](https://docs.alliancecan.ca/wiki/Available_software)

# %% [markdown]
# ## Run ISCE with S1
# - [JPL-NASA tutorial](https://github.com/uafgeoteach/GEOS657_MRS/blob/main/2024/GEOS657-Lab5-InSARwithtopsApp.ipynb)

# %% [markdown]
# # MintPy

# %% [markdown]
# ## Installation
# - [Mintpy Installation](https://mintpy.readthedocs.io/en/stable/installation/)

# %% [markdown]
# ## Important links:
#
# - [Mintpy's templates](https://github.com/insarlab/MintPy/tree/main/docs/templates)
#
# - [Mintpy's directories](https://github.com/insarlab/MintPy/blob/main/docs/dir_structure.md)

# %% [markdown]
# ## Run MintPy with S1
# `wget https://zenodo.org/record/3952953/files/FernandinaSenDT128.tar.xz
#
# tar -xvJf FernandinaSenDT128.tar.xz
#
# cd FernandinaSenDT128/mintpy
#
# smallbaselineApp.py FernandinaSenDT128.txt`

# %% [markdown]
# [FernandinaSenDT128.txt](https://github.com/insarlab/MintPy/blob/main/docs/templates/FernandinaSenDT128.txt)
